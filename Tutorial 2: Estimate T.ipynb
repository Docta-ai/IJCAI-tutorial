# %% [markdown]
# # Tutorial 2: Learning the noise rate in the labels without knowing the ground truth
#
# This module will go through examples showing how one can estimate the hidden noise transition matrix that controls the generation of noisy labels, without using ground truth annotations.
#
# The knowledge of noise rate plays a central role in understanding the quality of data and in building robust training approaches.
#
# The figure below illustrates a typical workflow of estimating the noise transition matrix $T$.
#
# In this tutorial, the approaches we will cover include a data-centric approach based on clusterability [[paper 1](https://proceedings.mlr.press/v139/zhu21e.html), [paper 2](https://proceedings.mlr.press/v162/zhu22k.html)] and a learning-centric approach based on deep neural networks [[paper]](https://proceedings.mlr.press/v162/yang22p.html). See the following figure for an illustration of inferring the transition matrix.

# %%
from IPython.display import Image
display(Image(filename='tutorial_imgs/est_T.png', width = 750, height = 400))
