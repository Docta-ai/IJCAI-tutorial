# %% [markdown]
# # 4.  Noise label detection
#
# This section will go through examples that explain how one can implement a detection algorithm to identify the wrong labels in a training dataset. The approaches we will cover include a data-centric method (CORES) [[paper]](https://proceedings.mlr.press/v162/zhu22a.html) and a learning-centric method (SimiFeat) [[paper]](https://proceedings.mlr.press/v162/zhu22a.html).
#
# The figure below is an illustration of the noisy label detection procedure.

# %%
from IPython.display import Image
display(Image(filename='tutorial_imgs/detect_label.png', width = 750, height = 400))
